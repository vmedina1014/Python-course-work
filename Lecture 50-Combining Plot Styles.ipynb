# %%
import numpy as np
from numpy.random import randn
import pandas as pd

from scipy import stats

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
dataset=randn(100)

# %%
sns.distplot(dataset,bins=25)

# %%
sns.distplot(dataset,bins=25,rug=True,hist=False)

# %%
sns.distplot(dataset,bins=25,kde_kws={'color':'indianred','label':'KDE PLOT'}, hist_kws={'color':'blue','label':'Histo'})

# %%
from pandas import Series

# %%
ser1=Series(dataset,name='My_data')
ser1
# Out:
# 0     0.540176
# 1    -2.349720
# 2     1.353016
# 3    -0.592478
# 4    -0.496817
# 5     0.813518
# 6     0.806087
# 7     1.361871
# 8     0.780130
# 9     1.903224
# 10   -0.893122
# 11    0.366487
# 12    0.243101
# 13   -1.947184
# 14   -0.982224
# 15    1.265392
# 16   -0.658054
# 17   -0.223444
# 18   -1.236182
# 19   -0.657762
# 20    0.108513
# 21   -0.219076
# 22   -1.439224
# 23    0.283986
# 24   -1.369576
# 25   -0.802260
# 26   -1.985637
# 27   -1.166066
# 28    0.391433
# 29    1.900592
#         ...
# 70    1.238842
# 71   -0.505787
# 72    0.842181
# 73    1.400490
# 74   -1.295274
# 75   -0.659222
# 76   -1.622725
# 77   -1.182418
# 78   -0.817979
# 79   -0.305466
# 80    1.783576
# 81   -0.319321
# 82   -0.410235
# 83    0.227004
# 84   -0.635446
# 85    0.074350
# 86    0.657718
# 87    1.158425
# 88    0.247924
# 89    1.150182
# 90   -0.133698
# 91    2.202323
# 92   -0.241655
# 93    2.704860
# 94   -0.515967
# 95    1.426560
# 96   -1.174340
# 97    1.059799
# 98   -0.441673
# 99   -0.358234
# Name: My_data, dtype: float64

# %%
sns.distplot(ser1,bins=25)
